# %% [markdown]
# # 02: cohort_description
#
# > **Status**: stub — to be implemented in Stage I

# %%
# Setup
# %load_ext autoreload
# %autoreload 2
from cpet_stage1.utils.logging import setup_logging
from cpet_stage1.utils.seed import set_global_seed
setup_logging()
set_global_seed()
